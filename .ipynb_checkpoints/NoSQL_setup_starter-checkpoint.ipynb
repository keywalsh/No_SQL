# %% [markdown]
# # Eat Safe, Love

# %% [markdown]
# ## Part 1: Database and Jupyter Notebook Set Up

# %% [markdown]
# Import the data provided in the `establishments.json` file from your Terminal. Name the database `uk_food` and the collection `establishments`.
#
# Within this markdown cell, copy the line of text you used to import the data from your Terminal. This way, future analysts will be able to repeat your process.
#
# e.g.: Import the dataset with `YOUR IMPORT TEXT HERE`

# %%
# Import dependencies
from pymongo import MongoClient
from pprint import pprint

# %%
# Create an instance of MongoClient
mongo = MongoClient(port=27017)

# %%
# confirm that our new database was created
print(mongo.list_database_names())
# Out:
# ['admin', 'autosaurus', 'classDB', 'config', 'epa', 'fruits_db', 'gardenDB', 'local', 'met', 'petsitly_marketing', 'travel_db', 'uk_food']

# %%
# assign the uk_food database to a variable name
db = mongo['uk_food']

# %%
# review the collections in our new database
print(db.list_collection_names())
# Out:
# ['establishments']

# %%
# review a document in the establishments collection
pprint(db.establishments.find_one())
# Out:
# {'AddressLine1': 'The Bay',
#  'AddressLine2': 'St Margarets Bay',
#  'AddressLine3': 'Kent',
#  'AddressLine4': '',
#  'BusinessName': 'Refreshment Kiosk',
#  'BusinessType': 'Restaurant/Cafe/Canteen',
#  'BusinessTypeID': 1,
#  'ChangesByServerID': 0,
#  'Distance': 4587.347174863443,
#  'FHRSID': 254719,
#  'LocalAuthorityBusinessID': 'PI/000069980',
#  'LocalAuthorityCode': '182',
#  'LocalAuthorityEmailAddress': 'publicprotection@dover.gov.uk',
#  'LocalAuthorityName': 'Dover',
#  'LocalAuthorityWebSite': 'http://www.dover.gov.uk/',
#  'NewRatingPending': False,
#  'Phone': '',
#  'PostCode': 'CT15 6DY',
#  'RatingDate': '2022-03-24T00:00:00',
#  'RatingKey': 'fhrs_5_en-gb',
#  'RatingValue': '5',
#  'RightToReply': '',
#  'SchemeType': 'FHRS',
#  '_id': ObjectId('641e16246567588cbd6f7881'),
#  'geocode': {'latitude': '51.152225', 'longitude': '1.387974'},
#  'links': [{'href': 'https://api.ratings.food.gov.uk/establishments/254719',
#             'rel': 'self'}],
#  'meta': {'dataSource': None,
#           'extractDate': '0001-01-01T00:00:00',
#           'itemCount': 0,
#           'pageNumber': 0,
#           'pageSize': 0,
#           'returncode': None,
#           'totalCount': 0,
#           'totalPages': 0},
#  'scores': {'ConfidenceInManagement': 5, 'Hygiene': 0, 'Structural': 5}}

# %%
# assign the collection to a variable
establishments = db['establishments']

# %%
query = {"BusinessName":'Penang Flavours'}
print("Number of Penang Flavours: ", establishments.count_documents(query))
# Out:
# Number of Penang Flavours:  0

# %% [markdown]
# ## Part 2: Update the Database

# %% [markdown]
# 1. An exciting new halal restaurant just opened in Greenwich, but hasn't been rated yet. The magazine has asked you to include it in your analysis. Add the following restaurant "Penang Flavours" to the database.

# %%
# Create a dictionary for the new restaurant data
halal = {
    "BusinessName":"Penang Flavours",
    "BusinessType":"Restaurant/Cafe/Canteen",
    "BusinessTypeID":"",
    "AddressLine1":"Penang Flavours",
    "AddressLine2":"146A Plumstead Rd",
    "AddressLine3":"London",
    "AddressLine4":"",
    "PostCode":"SE18 7DY",
    "Phone":"",
    "LocalAuthorityCode":"511",
    "LocalAuthorityName":"Greenwich",
    "LocalAuthorityWebSite":"http://www.royalgreenwich.gov.uk",
    "LocalAuthorityEmailAddress":"health@royalgreenwich.gov.uk",
    "scores":{
        "Hygiene":"",
        "Structural":"",
        "ConfidenceInManagement":""
    },
    "SchemeType":"FHRS",
    "geocode":{
        "longitude":"0.08384000",
        "latitude":"51.49014200"
    },
    "RightToReply":"",
    "Distance":4623.9723280747176,
    "NewRatingPending":True
}

# %%
# Insert the new restaurant into the collection
establishments.insert_one(halal)

# %%
# Check that the new restaurant was inserted
pprint(establishments.find_one({"BusinessName":"Penang Flavours"}))
# Out:
# {'AddressLine1': 'Penang Flavours',
#  'AddressLine2': '146A Plumstead Rd',
#  'AddressLine3': 'London',
#  'AddressLine4': '',
#  'BusinessName': 'Penang Flavours',
#  'BusinessType': 'Restaurant/Cafe/Canteen',
#  'BusinessTypeID': '',
#  'Distance': 4623.972328074718,
#  'LocalAuthorityCode': '511',
#  'LocalAuthorityEmailAddress': 'health@royalgreenwich.gov.uk',
#  'LocalAuthorityName': 'Greenwich',
#  'LocalAuthorityWebSite': 'http://www.royalgreenwich.gov.uk',
#  'NewRatingPending': True,
#  'Phone': '',
#  'PostCode': 'SE18 7DY',
#  'RightToReply': '',
#  'SchemeType': 'FHRS',
#  '_id': ObjectId('641e16940738d795e8268127'),
#  'geocode': {'latitude': '51.49014200', 'longitude': '0.08384000'},
#  'scores': {'ConfidenceInManagement': '', 'Hygiene': '', 'Structural': ''}}

# %%
# Check if any remaining documents include Dover
query = {"BusinessName":'Penang Flavours'}
print("Number of Penang Flavours: ", establishments.count_documents(query))
# Out:
# Number of Penang Flavours:  1

# %% [markdown]
# 2. Find the BusinessTypeID for "Restaurant/Cafe/Canteen" and return only the `BusinessTypeID` and `BusinessType` fields.

# %%
# Find the BusinessTypeID for "Restaurant/Cafe/Canteen" and return only the BusinessTypeID and BusinessType fields
query = {'BusinessType': 'Restaurant/Cafe/Canteen'}
fields = {'BusinessTypeID': 1, 'BusinessType': 1}
pprint(establishments.find_one(query, projection=fields))
# Out:
# {'BusinessType': 'Restaurant/Cafe/Canteen',
#  'BusinessTypeID': 1,
#  '_id': ObjectId('641e16246567588cbd6f7881')}

# %% [markdown]
# 3. Update the new restaurant with the `BusinessTypeID` you found.

# %%
# Update the new restaurant with the correct BusinessTypeID
db.establishments.update_one(
    {"BusinessName":"Penang Flavours"},
    {'$set': 
        { "BusinessTypeID": 1}})

# %%
# Confirm that the new restaurant was updated
query = {"BusinessName":"Penang Flavours"}
pprint(establishments.find_one(query))
# Out:
# {'AddressLine1': 'Penang Flavours',
#  'AddressLine2': '146A Plumstead Rd',
#  'AddressLine3': 'London',
#  'AddressLine4': '',
#  'BusinessName': 'Penang Flavours',
#  'BusinessType': 'Restaurant/Cafe/Canteen',
#  'BusinessTypeID': 1,
#  'Distance': 4623.972328074718,
#  'LocalAuthorityCode': '511',
#  'LocalAuthorityEmailAddress': 'health@royalgreenwich.gov.uk',
#  'LocalAuthorityName': 'Greenwich',
#  'LocalAuthorityWebSite': 'http://www.royalgreenwich.gov.uk',
#  'NewRatingPending': True,
#  'Phone': '',
#  'PostCode': 'SE18 7DY',
#  'RightToReply': '',
#  'SchemeType': 'FHRS',
#  '_id': ObjectId('641e16940738d795e8268127'),
#  'geocode': {'latitude': '51.49014200', 'longitude': '0.08384000'},
#  'scores': {'ConfidenceInManagement': '', 'Hygiene': '', 'Structural': ''}}

# %% [markdown]
# 4. The magazine is not interested in any establishments in Dover, so check how many documents contain the Dover Local Authority. Then, remove any establishments within the Dover Local Authority from the database, and check the number of documents to ensure they were deleted.

# %%
# Find how many documents have LocalAuthorityName as "Dover"
query = {'LocalAuthorityName': 'Dover'}
print("Number of Dover LocalAuthority Locations:", establishments.count_documents(query))
# Out:
# Number of Dover LocalAuthority Locations: 994

# %%
# Delete all documents where LocalAuthorityName is "Dover"
query = {'LocalAuthorityName': 'Dover'}
establishments.delete_many(query)

# %%
# Check if any remaining documents include Dover
query = {'LocalAuthorityName': 'Dover'}
print("Number of Dover LocalAuthority Locations:", establishments.count_documents(query))
# Out:
# Number of Dover LocalAuthority Locations: 0

# %%
# Check that other documents remain with 'find_one'
pprint(db.establishments.find_one())
# Out:
# {'AddressLine1': 'East Cliff Pavilion',
#  'AddressLine2': 'Wear Bay Road',
#  'AddressLine3': 'Folkestone',
#  'AddressLine4': 'Kent',
#  'BusinessName': 'The Pavilion',
#  'BusinessType': 'Restaurant/Cafe/Canteen',
#  'BusinessTypeID': 1,
#  'ChangesByServerID': 0,
#  'Distance': 4591.765489457773,
#  'FHRSID': 1043695,
#  'LocalAuthorityBusinessID': 'PI/000073616',
#  'LocalAuthorityCode': '188',
#  'LocalAuthorityEmailAddress': 'foodteam@folkestone-hythe.gov.uk',
#  'LocalAuthorityName': 'Folkestone and Hythe',
#  'LocalAuthorityWebSite': 'http://www.folkestone-hythe.gov.uk',
#  'NewRatingPending': False,
#  'Phone': '',
#  'PostCode': 'CT19 6BL',
#  'RatingDate': '2018-04-04T00:00:00',
#  'RatingKey': 'fhrs_5_en-gb',
#  'RatingValue': '5',
#  'RightToReply': '',
#  'SchemeType': 'FHRS',
#  '_id': ObjectId('641e16246567588cbd6f7b69'),
#  'geocode': {'latitude': '51.083812', 'longitude': '1.195625'},
#  'links': [{'href': 'https://api.ratings.food.gov.uk/establishments/1043695',
#             'rel': 'self'}],
#  'meta': {'dataSource': None,
#           'extractDate': '0001-01-01T00:00:00',
#           'itemCount': 0,
#           'pageNumber': 0,
#           'pageSize': 0,
#           'returncode': None,
#           'totalCount': 0,
#           'totalPages': 0},
#  'scores': {'ConfidenceInManagement': 5, 'Hygiene': 5, 'Structural': 5}}

# %% [markdown]
# 5. Some of the number values are stored as strings, when they should be stored as numbers. Use `update_many` to convert `latitude` and `longitude` to decimal numbers.

# %%
# Change the data type from String to Decimal for longitude 
establishments.update_many({}, [ {'$set':{'geocode.longitude': {'$toDecimal': '$geocode.longitude'} }}])

# %%
# Change the data type from String to Decimal for latitude
establishments.update_many({}, [ {'$set':{'geocode.latitude': {'$toDecimal': '$geocode.latitude'} }}])

# %%
pprint(db.establishments.find_one())
# Out:
# {'AddressLine1': 'East Cliff Pavilion',
#  'AddressLine2': 'Wear Bay Road',
#  'AddressLine3': 'Folkestone',
#  'AddressLine4': 'Kent',
#  'BusinessName': 'The Pavilion',
#  'BusinessType': 'Restaurant/Cafe/Canteen',
#  'BusinessTypeID': 1,
#  'ChangesByServerID': 0,
#  'Distance': 4591.765489457773,
#  'FHRSID': 1043695,
#  'LocalAuthorityBusinessID': 'PI/000073616',
#  'LocalAuthorityCode': '188',
#  'LocalAuthorityEmailAddress': 'foodteam@folkestone-hythe.gov.uk',
#  'LocalAuthorityName': 'Folkestone and Hythe',
#  'LocalAuthorityWebSite': 'http://www.folkestone-hythe.gov.uk',
#  'NewRatingPending': False,
#  'Phone': '',
#  'PostCode': 'CT19 6BL',
#  'RatingDate': '2018-04-04T00:00:00',
#  'RatingKey': 'fhrs_5_en-gb',
#  'RatingValue': '5',
#  'RightToReply': '',
#  'SchemeType': 'FHRS',
#  '_id': ObjectId('641e16246567588cbd6f7b69'),
#  'geocode': {'latitude': Decimal128('51.083812'),
#              'longitude': Decimal128('1.195625')},
#  'links': [{'href': 'https://api.ratings.food.gov.uk/establishments/1043695',
#             'rel': 'self'}],
#  'meta': {'dataSource': None,
#           'extractDate': '0001-01-01T00:00:00',
#           'itemCount': 0,
#           'pageNumber': 0,
#           'pageSize': 0,
#           'returncode': None,
#           'totalCount': 0,
#           'totalPages': 0},
#  'scores': {'ConfidenceInManagement': 5, 'Hygiene': 5, 'Structural': 5}}

# %%
# Check that the coordinates are now numbers
list(establishments.aggregate([{
    
    '$project': 
        {

                'latitude': {'$isNumber': '$geocode.latitude'}, 
                'longitude': {'$isNumber': '$geocode.longitude'}
                 
        }
     
}]))
# Out:
# [{'_id': ObjectId('641e16246567588cbd6f7b69'),
#   'latitude': True,
#   'longitude': True},
#  {'_id': ObjectId('641e16246567588cbd6f7b6a'),
#   'latitude': True,
#   'longitude': True},
#  {'_id': ObjectId('641e16246567588cbd6f7b6b'),
#   'latitude': True,
#   'longitude': True},
#  {'_id': ObjectId('641e16246567588cbd6f7b6c'),
#   'latitude': True,
#   'longitude': True},
#  {'_id': ObjectId('641e16246567588cbd6f7b6d'),
#   'latitude': True,
#   'longitude': True},
#  {'_id': ObjectId('641e16246567588cbd6f7b6e'),
#   'latitude': True,
#   'longitude': True},
#  {'_id': ObjectId('641e16246567588cbd6f7b6f'),
#   'latitude': True,
#   'longitude': True},
#  {'_id': ObjectId('641e16246567588cbd6f7b71'),
#   'latitude': True,
#   'longitude': True},
#  {'_id': ObjectId('641e16246567588cbd6f7b72'),
#   'latitude': True,
#   'longitude': True},
#  {'_id': ObjectId('641e16246567588cbd6f7b73'),
#   'latitude': True,
#   'longitude': True},
#  {'_id': ObjectId('641e16246567588cbd6f7b74'),
#   'latitude': True,
#   'longitude': True},
#  {'_id': ObjectId('641e16246567588cbd6f7b75'),
#   'latitude': True,
#   'longitude': True},
#  {'_id': ObjectId('641e16246567588cbd6f7b76'),
#   'latitude': True,
#   'longitude': True},
#  {'_id': ObjectId('641e16246567588cbd6f7b77'),
#   'latitude': True,
#   'longitude': True},
#  {'_id': ObjectId('641e16246567588cbd6f7b78'),
#   'latitude': True,
#   'longitude': True},
#  {'_id': ObjectId('641e16246567588cbd6f7b79'),
#   'latitude': True,
#   'longitude': True},
#  {'_id': ObjectId('641e16246567588cbd6f7b7a'),
#   'latitude': True,
#   'longitude': True},
#  {'_id': ObjectId('641e16246567588cbd6f7b7b'),
#   'latitude': True,
#   'longitude': True},
#  {'_id': ObjectId('641e16246567588cbd6f7b7c'),
#   'latitude': True,
#   'longitude': True},
#  {'_id': ObjectId('641e16246567588cbd6f7b7d'),
#   'latitude': True,
#   'longitude': True},
#  {'_id': ObjectId('641e16246567588cbd6f7b7e'),
#   'latitude': True,
#   'longitude': True},
#  {'_id': ObjectId('641e16246567588cbd6f7b7f'),
#   'latitude': True,
#   'longitude': True},
#  {'_id': ObjectId('641e16246567588cbd6f7b80'),
#   'latitude': True,
#   'longitude': True},
#  {'_id': ObjectId('641e16246567588cbd6f7b81'),
#   'latitude': True,
#   'longitude': True},
#  {'_id': ObjectId('641e16246567588cbd6f7b82'),
#   'latitude': True,
#   'longitude': True},
#  {'_id': ObjectId('641e16246567588cbd6f7b83'),
#   'latitude': True,
#   'longitude': True},
#  {'_id': ObjectId('641e16246567588cbd6f7b84'),
#   'latitude': True,
#   'longitude': True},
#  {'_id': ObjectId('641e16246567588cbd6f7b85'),
#   'latitude': True,
#   'longitude': True},
#  {'_id': ObjectId('641e16246567588cbd6f7b86'),
#   'latitude': True,
#   'longitude': True},
#  {'_id': ObjectId('641e16246567588cbd6f7b87'),
#   'latitude': True,
#   'longitude': True},
#  {'_id': ObjectId('641e16246567588cbd6f7b88'),
#   'latitude': True,
#   'longitude': True},
#  {'_id': ObjectId('641e16246567588cbd6f7b89'),
#   'latitude': True,
#   'longitude': True},
#  {'_id': ObjectId('641e16246567588cbd6f7b8a'),
#   'latitude': True,
#   'longitude': True},
#  {'_id': ObjectId('641e16246567588cbd6f7b8b'),
#   'latitude': True,
#   'longitude': True},
#  {'_id': ObjectId('641e16246567588cbd6f7b8c'),
#   'latitude': True,
#   'longitude': True},
#  {'_id': ObjectId('641e16246567588cbd6f7b8d'),
#   'latitude': True,
#   'longitude': True},
#  {'_id': ObjectId('641e16246567588cbd6f7b8e'),
#   'latitude': True,
#   'longitude': True},
#  {'_id': ObjectId('641e16246567588cbd6f7b8f'),
#   'latitude': True,
#   'longitude': True},
#  {'_id': ObjectId('641e16246567588cbd6f7b90'),
#   'latitude': True,
#   'longitude': True},
#  {'_id': ObjectId('641e16246567588cbd6f7b91'),
#   'latitude': True,
#   'longitude': True},
#  {'_id': ObjectId('641e16246567588cbd6f7b92'),
#   'latitude': True,
#   'longitude': True},
#  {'_id': ObjectId('641e16246567588cbd6f7b93'),
#   'latitude': True,
#   'longitude': True},
#  {'_id': ObjectId('641e16246567588cbd6f7b95'),
#   'latitude': True,
#   'longitude': True},
#  {'_id': ObjectId('641e16246567588cbd6f7b96'),
#   'latitude': True,
#   'longitude': True},
#  {'_id': ObjectId('641e16246567588cbd6f7b97'),
#   'latitude': True,
#   'longitude': True},
#  {'_id': ObjectId('641e16246567588cbd6f7b98'),
#   'latitude': True,
#   'longitude': True},
#  {'_id': ObjectId('641e16246567588cbd6f7b99'),
#   'latitude': True,
#   'longitude': True},
#  {'_id': ObjectId('641e16246567588cbd6f7b9a'),
#   'latitude': True,
#   'longitude': True},
#  {'_id': ObjectId('641e16246567588cbd6f7b9c'),
#   'latitude': True,
#   'longitude': True},
#  {'_id': ObjectId('641e16246567588cbd6f7b9d'),
#   'latitude': True,
#   'longitude': True},
#  {'_id': ObjectId('641e16246567588cbd6f7b9e'),
#   'latitude': True,
#   'longitude': True},
#  {'_id': ObjectId('641e16246567588cbd6f7b9f'),
#   'latitude': True,
#   'longitude': True},
#  {'_id': ObjectId('641e16246567588cbd6f7ba1'),
#   'latitude': True,
#   'longitude': True},
#  {'_id': ObjectId('641e16246567588cbd6f7ba2'),
#   'latitude': True,
#   'longitude': True},
#  {'_id': ObjectId('641e16246567588cbd6f7ba3'),
#   'latitude': True,
#   'longitude': True},
#  {'_id': ObjectId('641e16246567588cbd6f7ba4'),
#   'latitude': True,
#   'longitude': True},
#  {'_id': ObjectId('641e16246567588cbd6f7ba6'),
#   'latitude': True,
#   'longitude': True},
#  {'_id': ObjectId('641e16246567588cbd6f7ba7'),
#   'latitude': True,
#   'longitude': True},
#  {'_id': ObjectId('641e16246567588cbd6f7ba8'),
#   'latitude': True,
#   'longitude': True},
#  {'_id': ObjectId('641e16246567588cbd6f7ba9'),
#   'latitude': True,
#   'longitude': True},
#  {'_id': ObjectId('641e16246567588cbd6f7baa'),
#   'latitude': True,
#   'longitude': True},
#  {'_id': ObjectId('641e16246567588cbd6f7bac'),
#   'latitude': True,
#   'longitude': True},
#  {'_id': ObjectId('641e16246567588cbd6f7bad'),
#   'latitude': True,
#   'longitude': True},
#  {'_id': ObjectId('641e16246567588cbd6f7bae'),
#   'latitude': True,
#   'longitude': True},
#  {'_id': ObjectId('641e16246567588cbd6f7baf'),
#   'latitude': True,
#   'longitude': True},
#  {'_id': ObjectId('641e16246567588cbd6f7bb0'),
#   'latitude': True,
#   'longitude': True},
#  {'_id': ObjectId('641e16246567588cbd6f7bb4'),
#   'latitude': True,
#   'longitude': True},
#  {'_id': ObjectId('641e16246567588cbd6f7bb5'),
#   'latitude': True,
#   'longitude': True},
#  {'_id': ObjectId('641e16246567588cbd6f7bb6'),
#   'latitude': True,
#   'longitude': True},
#  {'_id': ObjectId('641e16246567588cbd6f7bb7'),
#   'latitude': True,
#   'longitude': True},
#  {'_id': ObjectId('641e16246567588cbd6f7bb8'),
#   'latitude': True,
#   'longitude': True},
#  {'_id': ObjectId('641e16246567588cbd6f7bb9'),
#   'latitude': True,
#   'longitude': True},
#  {'_id': ObjectId('641e16246567588cbd6f7bba'),
#   'latitude': True,
#   'longitude': True},
#  {'_id': ObjectId('641e16246567588cbd6f7bbb'),
#   'latitude': True,
#   'longitude': True},
#  {'_id': ObjectId('641e16246567588cbd6f7bbc'),
#   'latitude': True,
#   'longitude': True},
#  {'_id': ObjectId('641e16246567588cbd6f7bbd'),
#   'latitude': True,
#   'longitude': True},
#  {'_id': ObjectId('641e16246567588cbd6f7bbe'),
#   'latitude': True,
#   'longitude': True},
#  {'_id': ObjectId('641e16246567588cbd6f7bbf'),
#   'latitude': True,
#   'longitude': True},
#  {'_id': ObjectId('641e16246567588cbd6f7bc0'),
#   'latitude': True,
#   'longitude': True},
#  {'_id': ObjectId('641e16246567588cbd6f7bc1'),
#   'latitude': True,
#   'longitude': True},
#  {'_id': ObjectId('641e16246567588cbd6f7bc2'),
#   'latitude': True,
#   'longitude': True},
#  {'_id': ObjectId('641e16246567588cbd6f7bc3'),
#   'latitude': True,
#   'longitude': True},
#  {'_id': ObjectId('641e16246567588cbd6f7bc4'),
#   'latitude': True,
#   'longitude': True},
#  {'_id': ObjectId('641e16246567588cbd6f7bc5'),
#   'latitude': True,
#   'longitude': True},
#  {'_id': ObjectId('641e16246567588cbd6f7bc6'),
#   'latitude': True,
#   'longitude': True},
#  {'_id': ObjectId('641e16246567588cbd6f7bc7'),
#   'latitude': True,
#   'longitude': True},
#  {'_id': ObjectId('641e16246567588cbd6f7bc9'),
#   'latitude': True,
#   'longitude': True},
#  {'_id': ObjectId('641e16246567588cbd6f7bca'),
#   'latitude': True,
#   'longitude': True},
#  {'_id': ObjectId('641e16246567588cbd6f7bcb'),
#   'latitude': True,
#   'longitude': True},
#  {'_id': ObjectId('641e16246567588cbd6f7bcc'),
#   'latitude': True,
#   'longitude': True},
#  {'_id': ObjectId('641e16246567588cbd6f7bcd'),
#   'latitude': True,
#   'longitude': True},
#  {'_id': ObjectId('641e16246567588cbd6f7bce'),
#   'latitude': True,
#   'longitude': True},
#  {'_id': ObjectId('641e16246567588cbd6f7bcf'),
#   'latitude': True,
#   'longitude': True},
#  {'_id': ObjectId('641e16246567588cbd6f7bd0'),
#   'latitude': True,
#   'longitude': True},
#  {'_id': ObjectId('641e16246567588cbd6f7bd1'),
#   'latitude': True,
#   'longitude': True},
#  {'_id': ObjectId('641e16246567588cbd6f7bd2'),
#   'latitude': True,
#   'longitude': True},
#  {'_id': ObjectId('641e16246567588cbd6f7bd3'),
#   'latitude': True,
#   'longitude': True},
#  {'_id': ObjectId('641e16246567588cbd6f7bd4'),
#   'latitude': True,
#   'longitude': True},
#  {'_id': ObjectId('641e16246567588cbd6f7bd5'),
#   'latitude': True,
#   'longitude': True},
#  {'_id': ObjectId('641e16246567588cbd6f7bd6'),
#   'latitude': True,
#   'longitude': True},
#  {'_id': ObjectId('641e16246567588cbd6f7bd7'),
#   'latitude': True,
#   'longitude': True},
#  {'_id': ObjectId('641e16246567588cbd6f7bd8'),
#   'latitude': True,
#   'longitude': True},
#  {'_id': ObjectId('641e16246567588cbd6f7bd9'),
#   'latitude': True,
#   'longitude': True},
#  {'_id': ObjectId('641e16246567588cbd6f7bda'),
#   'latitude': True,
#   'longitude': True},
#  {'_id': ObjectId('641e16246567588cbd6f7bdb'),
#   'latitude': True,
#   'longitude': True},
#  {'_id': ObjectId('641e16246567588cbd6f7bdc'),
#   'latitude': True,
#   'longitude': True},
#  {'_id': ObjectId('641e16246567588cbd6f7bdd'),
#   'latitude': True,
#   'longitude': True},
#  {'_id': ObjectId('641e16246567588cbd6f7bde'),
#   'latitude': True,
#   'longitude': True},
#  {'_id': ObjectId('641e16246567588cbd6f7bdf'),
#   'latitude': True,
#   'longitude': True},
#  {'_id': ObjectId('641e16246567588cbd6f7be0'),
#   'latitude': True,
#   'longitude': True},
#  {'_id': ObjectId('641e16246567588cbd6f7be1'),
#   'latitude': True,
#   'longitude': True},
#  {'_id': ObjectId('641e16246567588cbd6f7be2'),
#   'latitude': True,
#   'longitude': True},
#  {'_id': ObjectId('641e16246567588cbd6f7be3'),
#   'latitude': True,
#   'longitude': True},
#  {'_id': ObjectId('641e16246567588cbd6f7be4'),
#   'latitude': True,
#   'longitude': True},
#  {'_id': ObjectId('641e16246567588cbd6f7be5'),
#   'latitude': True,
#   'longitude': True},
#  {'_id': ObjectId('641e16246567588cbd6f7be6'),
#   'latitude': True,
#   'longitude': True},
#  {'_id': ObjectId('641e16246567588cbd6f7be7'),
#   'latitude': True,
#   'longitude': True},
#  {'_id': ObjectId('641e16246567588cbd6f7be8'),
#   'latitude': True,
#   'longitude': True},
#  {'_id': ObjectId('641e16246567588cbd6f7be9'),
#   'latitude': True,
#   'longitude': True},
#  {'_id': ObjectId('641e16246567588cbd6f7bea'),
#   'latitude': True,
#   'longitude': True},
#  {'_id': ObjectId('641e16246567588cbd6f7beb'),
#   'latitude': True,
#   'longitude': True},
#  {'_id': ObjectId('641e16246567588cbd6f7bec'),
#   'latitude': True,
#   'longitude': True},
#  {'_id': ObjectId('641e16246567588cbd6f7bed'),
#   'latitude': True,
#   'longitude': True},
#  {'_id': ObjectId('641e16246567588cbd6f7bee'),
#   'latitude': True,
#   'longitude': True},
#  {'_id': ObjectId('641e16246567588cbd6f7bef'),
#   'latitude': True,
#   'longitude': True},
#  {'_id': ObjectId('641e16246567588cbd6f7bf0'),
#   'latitude': True,
#   'longitude': True},
#  {'_id': ObjectId('641e16246567588cbd6f7bf1'),
#   'latitude': True,
#   'longitude': True},
#  {'_id': ObjectId('641e16246567588cbd6f7bf2'),
#   'latitude': True,
#   'longitude': True},
#  {'_id': ObjectId('641e16246567588cbd6f7bf3'),
#   'latitude': True,
#   'longitude': True},
#  {'_id': ObjectId('641e16246567588cbd6f7bf4'),
#   'latitude': True,
#   'longitude': True},
#  {'_id': ObjectId('641e16246567588cbd6f7bf5'),
#   'latitude': True,
#   'longitude': True},
#  {'_id': ObjectId('641e16246567588cbd6f7bf6'),
#   'latitude': True,
#   'longitude': True},
#  {'_id': ObjectId('641e16246567588cbd6f7bf7'),
#   'latitude': True,
#   'longitude': True},
#  {'_id': ObjectId('641e16246567588cbd6f7bf8'),
#   'latitude': True,
#   'longitude': True},
#  {'_id': ObjectId('641e16246567588cbd6f7bf9'),
#   'latitude': True,
#   'longitude': True},
#  {'_id': ObjectId('641e16246567588cbd6f7bfa'),
#   'latitude': True,
#   'longitude': True},
#  {'_id': ObjectId('641e16246567588cbd6f7bfb'),
#   'latitude': True,
#   'longitude': True},
#  {'_id': ObjectId('641e16246567588cbd6f7bfc'),
#   'latitude': True,
#   'longitude': True},
#  {'_id': ObjectId('641e16246567588cbd6f7bfd'),
#   'latitude': True,
#   'longitude': True},
#  {'_id': ObjectId('641e16246567588cbd6f7bfe'),
#   'latitude': True,
#   'longitude': True},
#  {'_id': ObjectId('641e16246567588cbd6f7bff'),
#   'latitude': True,
#   'longitude': True},
#  {'_id': ObjectId('641e16246567588cbd6f7c00'),
#   'latitude': True,
#   'longitude': True},
#  {'_id': ObjectId('641e16246567588cbd6f7c01'),
#   'latitude': True,
#   'longitude': True},
#  {'_id': ObjectId('641e16246567588cbd6f7c02'),
#   'latitude': True,
#   'longitude': True},
#  {'_id': ObjectId('641e16246567588cbd6f7c03'),
#   'latitude': True,
#   'longitude': True},
#  {'_id': ObjectId('641e16246567588cbd6f7c04'),
#   'latitude': True,
#   'longitude': True},
#  {'_id': ObjectId('641e16246567588cbd6f7c05'),
#   'latitude': True,
#   'longitude': True},
#  {'_id': ObjectId('641e16246567588cbd6f7c06'),
#   'latitude': True,
#   'longitude': True},
#  {'_id': ObjectId('641e16246567588cbd6f7c07'),
#   'latitude': True,
#   'longitude': True},
#  {'_id': ObjectId('641e16246567588cbd6f7c08'),
#   'latitude': True,
#   'longitude': True},
#  {'_id': ObjectId('641e16246567588cbd6f7c09'),
#   'latitude': True,
#   'longitude': True},
#  {'_id': ObjectId('641e16246567588cbd6f7c0a'),
#   'latitude': True,
#   'longitude': True},
#  {'_id': ObjectId('641e16246567588cbd6f7c0b'),
#   'latitude': True,
#   'longitude': True},
#  {'_id': ObjectId('641e16246567588cbd6f7c0d'),
#   'latitude': True,
#   'longitude': True},
#  {'_id': ObjectId('641e16246567588cbd6f7c0e'),
#   'latitude': True,
#   'longitude': True},
#  {'_id': ObjectId('641e16246567588cbd6f7c0f'),
#   'latitude': True,
#   'longitude': True},
#  {'_id': ObjectId('641e16246567588cbd6f7c10'),
#   'latitude': True,
#   'longitude': True},
#  {'_id': ObjectId('641e16246567588cbd6f7c11'),
#   'latitude': True,
#   'longitude': True},
#  {'_id': ObjectId('641e16246567588cbd6f7c13'),
#   'latitude': True,
#   'longitude': True},
#  {'_id': ObjectId('641e16246567588cbd6f7c14'),
#   'latitude': True,
#   'longitude': True},
#  {'_id': ObjectId('641e16246567588cbd6f7c15'),
#   'latitude': True,
#   'longitude': True},
#  {'_id': ObjectId('641e16246567588cbd6f7c16'),
#   'latitude': True,
#   'longitude': True},
#  {'_id': ObjectId('641e16246567588cbd6f7c17'),
#   'latitude': True,
#   'longitude': True},
#  {'_id': ObjectId('641e16246567588cbd6f7c18'),
#   'latitude': True,
#   'longitude': True},
#  {'_id': ObjectId('641e16246567588cbd6f7c19'),
#   'latitude': True,
#   'longitude': True},
#  {'_id': ObjectId('641e16246567588cbd6f7c1a'),
#   'latitude': True,
#   'longitude': True},
#  {'_id': ObjectId('641e16246567588cbd6f7c1c'),
#   'latitude': True,
#   'longitude': True},
#  {'_id': ObjectId('641e16246567588cbd6f7c1d'),
#   'latitude': True,
#   'longitude': True},
#  {'_id': ObjectId('641e16246567588cbd6f7c1e'),
#   'latitude': True,
#   'longitude': True},
#  {'_id': ObjectId('641e16246567588cbd6f7c1f'),
#   'latitude': True,
#   'longitude': True},
#  {'_id': ObjectId('641e16246567588cbd6f7c20'),
#   'latitude': True,
#   'longitude': True},
#  {'_id': ObjectId('641e16246567588cbd6f7c21'),
#   'latitude': True,
#   'longitude': True},
#  {'_id': ObjectId('641e16246567588cbd6f7c22'),
#   'latitude': True,
#   'longitude': True},
#  {'_id': ObjectId('641e16246567588cbd6f7c23'),
#   'latitude': True,
#   'longitude': True},
#  {'_id': ObjectId('641e16246567588cbd6f7c24'),
#   'latitude': True,
#   'longitude': True},
#  {'_id': ObjectId('641e16246567588cbd6f7c25'),
#   'latitude': True,
#   'longitude': True},
#  {'_id': ObjectId('641e16246567588cbd6f7c26'),
#   'latitude': True,
#   'longitude': True},
#  {'_id': ObjectId('641e16246567588cbd6f7c27'),
#   'latitude': True,
#   'longitude': True},
#  {'_id': ObjectId('641e16246567588cbd6f7c28'),
#   'latitude': True,
#   'longitude': True},
#  {'_id': ObjectId('641e16246567588cbd6f7c29'),
#   'latitude': True,
#   'longitude': True},
#  {'_id': ObjectId('641e16246567588cbd6f7c2a'),
#   'latitude': True,
#   'longitude': True},
#  {'_id': ObjectId('641e16246567588cbd6f7c2b'),
#   'latitude': True,
#   'longitude': True},
#  {'_id': ObjectId('641e16246567588cbd6f7c2c'),
#   'latitude': True,
#   'longitude': True},
#  {'_id': ObjectId('641e16246567588cbd6f7c2e'),
#   'latitude': True,
#   'longitude': True},
#  {'_id': ObjectId('641e16246567588cbd6f7c2f'),
#   'latitude': True,
#   'longitude': True},
#  {'_id': ObjectId('641e16246567588cbd6f7c30'),
#   'latitude': True,
#   'longitude': True},
#  {'_id': ObjectId('641e16246567588cbd6f7c31'),
#   'latitude': True,
#   'longitude': True},
#  {'_id': ObjectId('641e16246567588cbd6f7c32'),
#   'latitude': True,
#   'longitude': True},
#  {'_id': ObjectId('641e16246567588cbd6f7c33'),
#   'latitude': True,
#   'longitude': True},
#  {'_id': ObjectId('641e16246567588cbd6f7c34'),
#   'latitude': True,
#   'longitude': True},
#  {'_id': ObjectId('641e16246567588cbd6f7c35'),
#   'latitude': True,
#   'longitude': True},
#  {'_id': ObjectId('641e16246567588cbd6f7c36'),
#   'latitude': True,
#   'longitude': True},
#  {'_id': ObjectId('641e16246567588cbd6f7c37'),
#   'latitude': True,
#   'longitude': True},
#  {'_id': ObjectId('641e16246567588cbd6f7c38'),
#   'latitude': True,
#   'longitude': True},
#  {'_id': ObjectId('641e16246567588cbd6f7c39'),
#   'latitude': True,
#   'longitude': True},
#  {'_id': ObjectId('641e16246567588cbd6f7c3a'),
#   'latitude': True,
#   'longitude': True},
#  {'_id': ObjectId('641e16246567588cbd6f7c3b'),
#   'latitude': True,
#   'longitude': True},
#  {'_id': ObjectId('641e16246567588cbd6f7c3c'),
#   'latitude': True,
#   'longitude': True},
#  {'_id': ObjectId('641e16246567588cbd6f7c3d'),
#   'latitude': True,
#   'longitude': True},
#  {'_id': ObjectId('641e16246567588cbd6f7c3e'),
#   'latitude': True,
#   'longitude': True},
#  {'_id': ObjectId('641e16246567588cbd6f7c3f'),
#   'latitude': True,
#   'longitude': True},
#  {'_id': ObjectId('641e16246567588cbd6f7c40'),
#   'latitude': True,
#   'longitude': True},
#  {'_id': ObjectId('641e16246567588cbd6f7c41'),
#   'latitude': True,
#   'longitude': True},
#  {'_id': ObjectId('641e16246567588cbd6f7c42'),
#   'latitude': True,
#   'longitude': True},
#  {'_id': ObjectId('641e16246567588cbd6f7c43'),
#   'latitude': True,
#   'longitude': True},
#  {'_id': ObjectId('641e16246567588cbd6f7c44'),
#   'latitude': True,
#   'longitude': True},
#  {'_id': ObjectId('641e16246567588cbd6f7c45'),
#   'latitude': True,
#   'longitude': True},
#  {'_id': ObjectId('641e16246567588cbd6f7c46'),
#   'latitude': True,
#   'longitude': True},
#  {'_id': ObjectId('641e16246567588cbd6f7c47'),
#   'latitude': True,
#   'longitude': True},
#  {'_id': ObjectId('641e16246567588cbd6f7c48'),
#   'latitude': True,
#   'longitude': True},
#  {'_id': ObjectId('641e16246567588cbd6f7c49'),
#   'latitude': True,
#   'longitude': True},
#  {'_id': ObjectId('641e16246567588cbd6f7c4a'),
#   'latitude': True,
#   'longitude': True},
#  {'_id': ObjectId('641e16246567588cbd6f7c4b'),
#   'latitude': True,
#   'longitude': True},
#  {'_id': ObjectId('641e16246567588cbd6f7c4c'),
#   'latitude': True,
#   'longitude': True},
#  {'_id': ObjectId('641e16246567588cbd6f7c4d'),
#   'latitude': True,
#   'longitude': True},
#  {'_id': ObjectId('641e16246567588cbd6f7c4e'),
#   'latitude': True,
#   'longitude': True},
#  {'_id': ObjectId('641e16246567588cbd6f7c4f'),
#   'latitude': True,
#   'longitude': True},
#  {'_id': ObjectId('641e16246567588cbd6f7c50'),
#   'latitude': True,
#   'longitude': True},
#  {'_id': ObjectId('641e16246567588cbd6f7c51'),
#   'latitude': True,
#   'longitude': True},
#  {'_id': ObjectId('641e16246567588cbd6f7c52'),
#   'latitude': True,
#   'longitude': True},
#  {'_id': ObjectId('641e16246567588cbd6f7c53'),
#   'latitude': True,
#   'longitude': True},
#  {'_id': ObjectId('641e16246567588cbd6f7c54'),
#   'latitude': True,
#   'longitude': True},
#  {'_id': ObjectId('641e16246567588cbd6f7c55'),
#   'latitude': True,
#   'longitude': True},
#  {'_id': ObjectId('641e16246567588cbd6f7c56'),
#   'latitude': True,
#   'longitude': True},
#  {'_id': ObjectId('641e16246567588cbd6f7c57'),
#   'latitude': True,
#   'longitude': True},
#  {'_id': ObjectId('641e16246567588cbd6f7c58'),
#   'latitude': True,
#   'longitude': True},
#  {'_id': ObjectId('641e16246567588cbd6f7c59'),
#   'latitude': True,
#   'longitude': True},
#  {'_id': ObjectId('641e16246567588cbd6f7c5a'),
#   'latitude': True,
#   'longitude': True},
#  {'_id': ObjectId('641e16246567588cbd6f7c5b'),
#   'latitude': True,
#   'longitude': True},
#  {'_id': ObjectId('641e16246567588cbd6f7c5c'),
#   'latitude': True,
#   'longitude': True},
#  {'_id': ObjectId('641e16246567588cbd6f7c5d'),
#   'latitude': True,
#   'longitude': True},
#  {'_id': ObjectId('641e16246567588cbd6f7c5e'),
#   'latitude': True,
#   'longitude': True},
#  {'_id': ObjectId('641e16246567588cbd6f7c5f'),
#   'latitude': True,
#   'longitude': True},
#  {'_id': ObjectId('641e16246567588cbd6f7c60'),
#   'latitude': True,
#   'longitude': True},
#  {'_id': ObjectId('641e16246567588cbd6f7c61'),
#   'latitude': True,
#   'longitude': True},
#  {'_id': ObjectId('641e16246567588cbd6f7c62'),
#   'latitude': True,
#   'longitude': True},
#  {'_id': ObjectId('641e16246567588cbd6f7c63'),
#   'latitude': True,
#   'longitude': True},
#  {'_id': ObjectId('641e16246567588cbd6f7c64'),
#   'latitude': True,
#   'longitude': True},
#  {'_id': ObjectId('641e16246567588cbd6f7c65'),
#   'latitude': True,
#   'longitude': True},
#  {'_id': ObjectId('641e16246567588cbd6f7c66'),
#   'latitude': True,
#   'longitude': True},
#  {'_id': ObjectId('641e16246567588cbd6f7c67'),
#   'latitude': True,
#   'longitude': True},
#  {'_id': ObjectId('641e16246567588cbd6f7c68'),
#   'latitude': True,
#   'longitude': True},
#  {'_id': ObjectId('641e16246567588cbd6f7c69'),
#   'latitude': True,
#   'longitude': True},
#  {'_id': ObjectId('641e16246567588cbd6f7c6a'),
#   'latitude': True,
#   'longitude': True},
#  {'_id': ObjectId('641e16246567588cbd6f7c6b'),
#   'latitude': True,
#   'longitude': True},
#  {'_id': ObjectId('641e16246567588cbd6f7c6c'),
#   'latitude': True,
#   'longitude': True},
#  {'_id': ObjectId('641e16246567588cbd6f7c6d'),
#   'latitude': True,
#   'longitude': True},
#  {'_id': ObjectId('641e16246567588cbd6f7c6e'),
#   'latitude': True,
#   'longitude': True},
#  {'_id': ObjectId('641e16246567588cbd6f7c6f'),
#   'latitude': True,
#   'longitude': True},
#  {'_id': ObjectId('641e16246567588cbd6f7c70'),
#   'latitude': True,
#   'longitude': True},
#  {'_id': ObjectId('641e16246567588cbd6f7c71'),
#   'latitude': True,
#   'longitude': True},
#  {'_id': ObjectId('641e16246567588cbd6f7c72'),
#   'latitude': True,
#   'longitude': True},
#  {'_id': ObjectId('641e16246567588cbd6f7c73'),
#   'latitude': True,
#   'longitude': True},
#  {'_id': ObjectId('641e16246567588cbd6f7c74'),
#   'latitude': True,
#   'longitude': True},
#  {'_id': ObjectId('641e16246567588cbd6f7c75'),
#   'latitude': True,
#   'longitude': True},
#  {'_id': ObjectId('641e16246567588cbd6f7c76'),
#   'latitude': True,
#   'longitude': True},
#  {'_id': ObjectId('641e16246567588cbd6f7c77'),
#   'latitude': True,
#   'longitude': True},
#  {'_id': ObjectId('641e16246567588cbd6f7c78'),
#   'latitude': True,
#   'longitude': True},
#  {'_id': ObjectId('641e16246567588cbd6f7c79'),
#   'latitude': True,
#   'longitude': True},
#  {'_id': ObjectId('641e16246567588cbd6f7c7a'),
#   'latitude': True,
#   'longitude': True},
#  {'_id': ObjectId('641e16246567588cbd6f7c7b'),
#   'latitude': True,
#   'longitude': True},
#  {'_id': ObjectId('641e16246567588cbd6f7c7d'),
#   'latitude': True,
#   'longitude': True},
#  {'_id': ObjectId('641e16246567588cbd6f7c7e'),
#   'latitude': True,
#   'longitude': True},
#  {'_id': ObjectId('641e16246567588cbd6f7c7f'),
#   'latitude': True,
#   'longitude': True},
#  {'_id': ObjectId('641e16246567588cbd6f7c80'),
#   'latitude': True,
#   'longitude': True},
#  {'_id': ObjectId('641e16246567588cbd6f7c81'),
#   'latitude': True,
#   'longitude': True},
#  {'_id': ObjectId('641e16246567588cbd6f7c82'),
#   'latitude': True,
#   'longitude': True},
#  {'_id': ObjectId('641e16246567588cbd6f7c83'),
#   'latitude': True,
#   'longitude': True},
#  {'_id': ObjectId('641e16246567588cbd6f7c84'),
#   'latitude': True,
#   'longitude': True},
#  {'_id': ObjectId('641e16246567588cbd6f7c85'),
#   'latitude': True,
#   'longitude': True},
#  {'_id': ObjectId('641e16246567588cbd6f7c86'),
#   'latitude': True,
#   'longitude': True},
#  {'_id': ObjectId('641e16246567588cbd6f7c87'),
#   'latitude': True,
#   'longitude': True},
#  {'_id': ObjectId('641e16246567588cbd6f7c88'),
#   'latitude': True,
#   'longitude': True},
#  {'_id': ObjectId('641e16246567588cbd6f7c89'),
#   'latitude': True,
#   'longitude': True},
#  {'_id': ObjectId('641e16246567588cbd6f7c8a'),
#   'latitude': True,
#   'longitude': True},
#  {'_id': ObjectId('641e16246567588cbd6f7c8b'),
#   'latitude': True,
#   'longitude': True},
#  {'_id': ObjectId('641e16246567588cbd6f7c8c'),
#   'latitude': True,
#   'longitude': True},
#  {'_id': ObjectId('641e16246567588cbd6f7c8d'),
#   'latitude': True,
#   'longitude': True},
#  {'_id': ObjectId('641e16246567588cbd6f7c8e'),
#   'latitude': True,
#   'longitude': True},
#  {'_id': ObjectId('641e16246567588cbd6f7c8f'),
#   'latitude': True,
#   'longitude': True},
#  {'_id': ObjectId('641e16246567588cbd6f7c90'),
#   'latitude': True,
#   'longitude': True},
#  {'_id': ObjectId('641e16246567588cbd6f7c91'),
#   'latitude': True,
#   'longitude': True},
#  {'_id': ObjectId('641e16246567588cbd6f7c92'),
#   'latitude': True,
#   'longitude': True},
#  {'_id': ObjectId('641e16246567588cbd6f7c93'),
#   'latitude': True,
#   'longitude': True},
#  {'_id': ObjectId('641e16246567588cbd6f7c94'),
#   'latitude': True,
#   'longitude': True},
#  {'_id': ObjectId('641e16246567588cbd6f7c95'),
#   'latitude': True,
#   'longitude': True},
#  {'_id': ObjectId('641e16246567588cbd6f7c96'),
#   'latitude': True,
#   'longitude': True},
#  {'_id': ObjectId('641e16246567588cbd6f7c97'),
#   'latitude': True,
#   'longitude': True},
#  {'_id': ObjectId('641e16246567588cbd6f7c98'),
#   'latitude': True,
#   'longitude': True},
#  {'_id': ObjectId('641e16246567588cbd6f7c99'),
#   'latitude': True,
#   'longitude': True},
#  {'_id': ObjectId('641e16246567588cbd6f7c9a'),
#   'latitude': True,
#   'longitude': True},
#  {'_id': ObjectId('641e16246567588cbd6f7c9b'),
#   'latitude': True,
#   'longitude': True},
#  {'_id': ObjectId('641e16246567588cbd6f7c9c'),
#   'latitude': True,
#   'longitude': True},
#  {'_id': ObjectId('641e16246567588cbd6f7c9d'),
#   'latitude': True,
#   'longitude': True},
#  {'_id': ObjectId('641e16246567588cbd6f7c9e'),
#   'latitude': True,
#   'longitude': True},
#  {'_id': ObjectId('641e16246567588cbd6f7c9f'),
#   'latitude': True,
#   'longitude': True},
#  {'_id': ObjectId('641e16246567588cbd6f7ca0'),
#   'latitude': True,
#   'longitude': True},
#  {'_id': ObjectId('641e16246567588cbd6f7ca2'),
#   'latitude': True,
#   'longitude': True},
#  {'_id': ObjectId('641e16246567588cbd6f7ca3'),
#   'latitude': True,
#   'longitude': True},
#  {'_id': ObjectId('641e16246567588cbd6f7ca4'),
#   'latitude': True,
#   'longitude': True},
#  {'_id': ObjectId('641e16246567588cbd6f7ca5'),
#   'latitude': True,
#   'longitude': True},
#  {'_id': ObjectId('641e16246567588cbd6f7ca6'),
#   'latitude': True,
#   'longitude': True},
#  {'_id': ObjectId('641e16246567588cbd6f7ca7'),
#   'latitude': True,
#   'longitude': True},
#  {'_id': ObjectId('641e16246567588cbd6f7ca8'),
#   'latitude': True,
#   'longitude': True},
#  {'_id': ObjectId('641e16246567588cbd6f7ca9'),
#   'latitude': True,
#   'longitude': True},
#  {'_id': ObjectId('641e16246567588cbd6f7caa'),
#   'latitude': True,
#   'longitude': True},
#  {'_id': ObjectId('641e16246567588cbd6f7